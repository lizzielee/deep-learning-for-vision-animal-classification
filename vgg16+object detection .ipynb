# %%
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
from os import listdir, makedirs, getcwd, remove
print(os.listdir("../input"))

# Import packages
import time, copy
import seaborn as sns
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from PIL import Image
from torchvision import datasets, models, transforms
from torchvision.utils import make_grid
from torchvision.models.vgg import model_urls
from torch.utils.data import Dataset, DataLoader, random_split
from torch.utils.data.sampler import SubsetRandomSampler

from os.path import isfile, join, abspath, exists, isdir, expanduser

# Any results you write to the current directory are saved as output.
# Out:
# ['fork-of-fork-of-object-detection-train-val', 'nfork-of-object-detection-train-val', 'fork-of-fork-of-object-detection-t', 'fork-of-new-fork-of-fork-of-object-detection-train', 'iwildcam-2019-fgvc6', 'fork-of-object-detection-t', 'vgg16']

# %%
# !ls ../input/fork-of-object-detection-t
# Out:
# __notebook__.ipynb  __results__.html  o_test_set.zip
# __output__.json     custom.css	      test_df_neww.pkl

# %%
class_names = ['empty', 'deer', 'moose', 'squirrel', 'rodent', 'small_mammal', 'elk', 'pronghorn_antelope', 
               'rabbit', 'bighorn_sheep', 'fox', 'coyote', 'black_bear', 'raccoon', 'skunk', 'wolf', 
               'bobcat', 'cat', 'dog', 'opossum', 'bison', 'mountain_goat', 'mountain_lion']

# %%
import pickle

# Split into train_df and val_df
with open('../input/nfork-of-object-detection-train-val/train_df_tt.pkl', 'rb') as f:
    train_df = pickle.load(f)
with open('../input/nfork-of-object-detection-train-val/val_df_tt.pkl', 'rb') as f:
    val_df = pickle.load(f)
with open('../input/fork-of-fork-of-object-detection-t/test_df_neww.pkl', 'rb') as f:
    test_df = pickle.load(f)

# %%
import zipfile

train_path = '../created/nfork-of-object-detection-train-val/o_train_set'
#os.makedirs(train_path)
zFile = zipfile.ZipFile('../input/nfork-of-object-detection-train-val/o_train_set.zip', 'r')
    #ZipFile.namelist(): 获取ZIP文档内所有文件的名称列表
for fileM in zFile.namelist(): 
    zFile.extract(fileM, train_path)
zFile.close();

# %%
val_path = '../created/nfork-of-object-detection-train-val/o_val_set'
os.makedirs(val_path)
zFile = zipfile.ZipFile('../input/nfork-of-object-detection-train-val/o_val_set.zip', 'r')
#ZipFile.namelist(): 获取ZIP文档内所有文件的名称列表
for fileM in zFile.namelist(): 
    zFile.extract(fileM, val_path)
zFile.close();

# %%
test_path = '../created/fork-of-fork-of-object-detection-t/o_test_set'
os.makedirs(test_path)
zFile = zipfile.ZipFile('../input/fork-of-fork-of-object-detection-t/o_test_set.zip', "r")
#ZipFile.namelist(): 获取ZIP文档内所有文件的名称列表
for fileM in zFile.namelist(): 
    zFile.extract(fileM, test_path)
zFile.close();

# %%
train_data_dir = train_path
val_data_dir = val_path
test_data_dir = test_path

# %%
train_df
# Out:
#       category_id        date_captured      ...       location  rights_holder
# 60              0  2012-01-11 14:03:00      ...             36  Erin Boydston
# 72             17  2012-04-08 17:53:09      ...             88   Justin Brown
# 77             19  2011-07-28 21:34:12      ...             38   Justin Brown
# 110            11  2011-09-17 03:49:00      ...            120  Erin Boydston
# 118             1  2014-09-26 02:14:06      ...             25   Justin Brown
# 132            17  2012-03-15 07:10:53      ...             88   Justin Brown
# 177            18  2012-01-17 10:44:15      ...            105   Justin Brown
# 182             1  2015-02-20 19:31:44      ...             25   Justin Brown
# 185            11  2011-05-30 02:35:00      ...            120  Erin Boydston
# 187            13  2012-04-13 20:35:30      ...            115   Justin Brown
# 198            18  2011-01-03 17:33:24      ...            100   Justin Brown
# 211            11  2011-04-29 06:02:00      ...             29  Erin Boydston
# 212            11  2012-01-20 09:46:31      ...             43   Justin Brown
# 236            11  2012-04-02 12:54:12      ...             43   Justin Brown
# 256            18  2012-04-06 06:16:53      ...             88   Justin Brown
# 264             0  2014-06-07 10:26:54      ...            106  Erin Boydston
# 284            17  2010-10-17 04:08:15      ...            100   Justin Brown
# 314            11  2011-07-05 20:03:03      ...             46   Justin Brown
# 323             0  2011-12-28 09:59:00      ...             36  Erin Boydston
# 344            10  2014-03-20 22:24:54      ...              1   Justin Brown
# 360            11  2012-03-04 08:10:34      ...             43   Justin Brown
# 368            16  2013-10-03 18:15:51      ...             34   Justin Brown
# 373             0  2014-02-06 11:03:24      ...             26  Erin Boydston
# 384            19  2011-10-14 11:30:22      ...              7   Justin Brown
# 399            18  2011-01-03 17:33:09      ...            100   Justin Brown
# 402            13  2014-03-22 12:37:23      ...             23  Erin Boydston
# 405             1  2014-06-17 07:34:56      ...             70  Erin Boydston
# 421            16  2012-04-02 14:37:43      ...             43   Justin Brown
# 426            16  2012-02-02 18:24:30      ...             64   Justin Brown
# 453            14  2011-10-22 02:13:00      ...            120  Erin Boydston
# ...           ...                  ...      ...            ...            ...
# 15655          11  2011-08-03 15:56:30      ...              7   Justin Brown
# 15660           1  2015-04-09 22:43:53      ...             27   Justin Brown
# 15661          18  2011-11-14 12:28:02      ...             38   Justin Brown
# 15663          13  2011-03-18 03:38:42      ...            100   Justin Brown
# 15677          11  2012-04-02 07:08:44      ...             46   Justin Brown
# 15678          16  2011-12-11 16:55:00      ...             66  Erin Boydston
# 15686          16  2012-10-13 01:55:55      ...              0  Erin Boydston
# 15711           1  2013-10-15 23:34:26      ...              6   Justin Brown
# 15725          16  2011-09-18 07:45:26      ...            115   Justin Brown
# 15742           0  2014-01-16 13:10:18      ...             57  Erin Boydston
# 15746          13  2011-10-04 22:16:10      ...             40   Justin Brown
# 15749          18  2013-01-29 14:24:06      ...              0  Erin Boydston
# 15764           0  2011-04-19 12:20:00      ...             36  Erin Boydston
# 15770          16  2011-07-28 21:52:16      ...             51   Justin Brown
# 15774          14  2014-11-04 03:17:10      ...             32   Justin Brown
# 15800          13  2011-04-05 04:43:04      ...            100   Justin Brown
# 15816          16  2011-07-18 07:43:36      ...             46   Justin Brown
# 15826           1  2014-01-23 18:19:41      ...             41   Justin Brown
# 15836           0  2011-11-09 07:38:00      ...             36  Erin Boydston
# 15869          17  2011-12-25 08:48:09      ...             38   Justin Brown
# 15872          18  2011-03-08 11:54:00      ...             62  Erin Boydston
# 15879          18  2012-01-06 17:26:57      ...             90   Justin Brown
# 15885           1  2014-05-24 20:34:31      ...             44   Justin Brown
# 15902          11  2014-03-10 03:58:03      ...              1   Justin Brown
# 15937           1  2014-06-05 23:02:53      ...             41   Justin Brown
# 15939          11  2012-02-09 19:37:59      ...            130   Justin Brown
# 15977           1  2014-05-26 06:24:08      ...             44   Justin Brown
# 15978          11  2011-12-11 06:04:00      ...            120  Erin Boydston
# 15983          18  2012-04-24 11:12:33      ...             43   Justin Brown
# 15985          11  2011-03-26 23:56:00      ...            120  Erin Boydston
#
# [1484 rows x 7 columns]

# %%
#pd.DataFrame(train_df['category'].value_counts()).transpose()

# %%
#pd.DataFrame(val_df['category'].value_counts()).transpose()

# %%
# Arrange the dataset in pytorch ImageFolder way
class IWildCamDataset(Dataset):
    
    def __init__(self, df, root_dir, transform=None):
        """
        Args:
            df (pandas.DataFrame): Contains basic information.
            root_dir (string): The path where image data is saved.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.df = df
        self.root_dir = root_dir
        self.transform = transform
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        img_path = os.path.join(self.root_dir,
                                self.df.iloc[idx].file_name)
        with open(img_path, 'rb') as f:
            image = Image.open(f)
            image = image.convert('RGB')
        
        if('category_id' in self.df.iloc[idx]):
            category = self.df.iloc[idx].category_id
        else:
            # In test set, there is no given category. Here we will not return the category,
            # return the img_id instead. (Because we need to keep track of the img id during
            # testing)
            category = self.df.iloc[idx].id
        #if('file_name' in self.df.iloc[idx]):
         #   filename = self.df.iloc[idx].file_name

        # Transform
        if self.transform:
            image = self.transform(image)

        return image, category

# %%
data_transforms = transforms.Compose([
    transforms.Resize(256),  # 1. Resize smallest side to 256.
     transforms.CenterCrop(224), # 2. Crop the center 224x224 pixels.
     transforms.ToTensor(), # 3. Convert to pytorch tensor.
     transforms.Normalize(mean = [0.485, 0.456, 0.406],  # normalize.
                          std = [0.229, 0.224, 0.225])
])

# Get dataset
train_set = IWildCamDataset(train_df, train_data_dir, transform=data_transforms)
val_set   = IWildCamDataset(val_df, val_data_dir, transform=data_transforms)
test_set  = IWildCamDataset(test_df, test_data_dir, transform=data_transforms)

# %%
def show_img(input_img, title):
    img = input_img.clone()
    # undo img transformations.
    img = img.squeeze() # get rid of batch dim.
    # un-normalize pixel values.
    for t, m, s in zip(img, [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]):
        t.mul_(s).add_(m)
    plt.title(title)
    plt.imshow(img.transpose(0,2).transpose(0,1)); 
    plt.grid(False); plt.axis('off');

# %%
len(test_set)
# Out:
# 40664

# %%
test_set[200][0].shape
# Out:
# torch.Size([3, 224, 224])

# %%
# Load a pretrained model
model_ft = models.vgg16()
model_ft.load_state_dict(torch.load('../input/vgg16/vgg16.pth'))

# Freeze all the network except the final layer
for param in model_ft.parameters():
    param.requires_grad = False

# Alter the Linear layer for our classification problem

model_ft.classifier[-1] = nn.Linear(in_features=4096, out_features=len(class_names))
#num_ftrs = model_ft.classifier.in_features
#model_ft.classifier = nn.Linear(num_ftrs, len(class_names))

# %%
def train_model(model, loss_fn, batchSize, trainset, valset, optimizer, num_epochs=5, num_workers=4):
  
    # Shuffling is needed in case dataset is not shuffled by default.
    train_loader = torch.utils.data.DataLoader(dataset = trainset,
                                               batch_size = batchSize,
                                               num_workers = num_workers,
                                               shuffle = True)
    # We don't need to bach the validation set but let's do it anyway.
    val_loader = torch.utils.data.DataLoader(dataset = valset,
                                             batch_size = batchSize,
                                             num_workers = num_workers,
                                             shuffle = False) # No need.

    # log accuracies and losses.
    train_accuracies = []; val_accuracies = []
    train_losses = []; val_losses = []

    # GPU enabling.
    model = model.cuda()
    loss_fn = loss_fn.cuda()
    
    # Save the initial model weights
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    
    # Training loop. 
    for epoch in range(0, num_epochs):
        correct = 0.0
        cum_loss = 0.0

        # Make a pass over the training data.
        model.train()
        for (i, (inputs, labels)) in enumerate(train_loader):
            
            inputs = inputs.cuda()
            #print(inputs.shape)
            labels = labels.cuda()

            # Forward pass. (Prediction stage)
            scores = model(inputs)
            loss = loss_fn(scores, labels)

            # Count how many correct in this batch.
            max_scores, max_labels = scores.max(1)
            correct += (max_labels == labels).sum().item()
            cum_loss += loss.item()

            # Zero the gradients in the network.
            optimizer.zero_grad()

            # Backward pass. (Gradient computation stage)
            loss.backward()
            
            # Parameter updates (SGD step)
            optimizer.step()

            # Logging the current results on training.
            if (i + 1) % 100 == 0:
                print('Train-epoch %d. Iteration %05d, Avg-Loss: %.4f, Accuracy: %.4f' % 
                    (epoch, i + 1, cum_loss / (i + 1), correct / ((i + 1) * batchSize)))

        train_accuracies.append(correct / len(trainset))
        train_losses.append(cum_loss / (i + 1))   

        # Make a pass over the validation data.
        correct = 0.0
        cum_loss = 0.0
        model.eval()
        for (i, (inputs, labels)) in enumerate(val_loader):
            inputs = inputs.cuda()
            labels = labels.cuda()
            

            # Forward pass. (Prediction stage)
            scores = model(inputs)
            cum_loss += loss_fn(scores, labels).item()

            # Count how many correct in this batch.
            max_scores, max_labels = scores.max(1)
            correct += (max_labels == labels).sum().item()

        val_accuracies.append(correct / len(valset))
        val_losses.append(cum_loss / (i + 1))
        
         # We should keep saving the best model: deep copy the model
        if (correct / len(valset)) > best_acc:
            best_acc = (correct / len(valset))
            best_model_wts = copy.deepcopy(model.state_dict())

        # Logging the current results on validation.
        print('Validation-epoch %d. Avg-Loss: %.4f, Accuracy: %.4f' % 
            (epoch, cum_loss / (i + 1), correct / len(valset)))
    
    # Before return, we should set the model with the best model weights
    model.load_state_dict(best_model_wts)
    
    # Plot the losses & accuracies
    x = range(num_epochs)
    
    plt.figure()
    plt.plot(x, train_accuracies)
    plt.plot(x, val_accuracies)
    plt.title('Accuracy')
    plt.legend(['train_accuracy', 'val_accuracy'])
    
    plt.figure()
    plt.plot(x, train_losses)
    plt.plot(x, val_losses)
    plt.title('Loss')
    plt.legend(['train_loss', 'val_loss'])

# %%
batchSize = 70
loss_fn = nn.CrossEntropyLoss()
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.00085, momentum=0.95)

# Train model
train_model(model_ft, loss_fn, batchSize, train_set, val_set, optimizer_ft, num_epochs=100)
# Out:
# Validation-epoch 0. Avg-Loss: 1.4673, Accuracy: 0.6145
# Validation-epoch 1. Avg-Loss: 1.1477, Accuracy: 0.6522
# Validation-epoch 2. Avg-Loss: 0.9812, Accuracy: 0.7304
# Validation-epoch 3. Avg-Loss: 0.9028, Accuracy: 0.7507
# Validation-epoch 4. Avg-Loss: 0.8497, Accuracy: 0.7681
# Validation-epoch 5. Avg-Loss: 0.8384, Accuracy: 0.7710
# Validation-epoch 6. Avg-Loss: 0.8124, Accuracy: 0.7681
# Validation-epoch 7. Avg-Loss: 0.7926, Accuracy: 0.7652
# Validation-epoch 8. Avg-Loss: 0.7864, Accuracy: 0.7681
# Validation-epoch 9. Avg-Loss: 0.7617, Accuracy: 0.7797
# Validation-epoch 10. Avg-Loss: 0.7584, Accuracy: 0.7797
# Validation-epoch 11. Avg-Loss: 0.7537, Accuracy: 0.7826
# Validation-epoch 12. Avg-Loss: 0.7408, Accuracy: 0.7768
# Validation-epoch 13. Avg-Loss: 0.7338, Accuracy: 0.7884
# Validation-epoch 14. Avg-Loss: 0.7377, Accuracy: 0.7942
# Validation-epoch 15. Avg-Loss: 0.7319, Accuracy: 0.7884
# Validation-epoch 16. Avg-Loss: 0.7236, Accuracy: 0.7826
# Validation-epoch 17. Avg-Loss: 0.7170, Accuracy: 0.8000
# Validation-epoch 18. Avg-Loss: 0.7159, Accuracy: 0.7913
# Validation-epoch 19. Avg-Loss: 0.7118, Accuracy: 0.7942
# Validation-epoch 20. Avg-Loss: 0.7132, Accuracy: 0.7913
# Validation-epoch 21. Avg-Loss: 0.7041, Accuracy: 0.7913
# Validation-epoch 22. Avg-Loss: 0.7010, Accuracy: 0.8058
# Validation-epoch 23. Avg-Loss: 0.7046, Accuracy: 0.8000
# Validation-epoch 24. Avg-Loss: 0.6932, Accuracy: 0.8000
# Validation-epoch 25. Avg-Loss: 0.7021, Accuracy: 0.7855
# Validation-epoch 26. Avg-Loss: 0.6979, Accuracy: 0.7942
# Validation-epoch 27. Avg-Loss: 0.6857, Accuracy: 0.8000
# Validation-epoch 28. Avg-Loss: 0.6859, Accuracy: 0.8000
# Validation-epoch 29. Avg-Loss: 0.6833, Accuracy: 0.8058
# Validation-epoch 30. Avg-Loss: 0.6910, Accuracy: 0.8029
# Validation-epoch 31. Avg-Loss: 0.6753, Accuracy: 0.8029
# Validation-epoch 32. Avg-Loss: 0.6817, Accuracy: 0.8029
# Validation-epoch 33. Avg-Loss: 0.6823, Accuracy: 0.8000
# Validation-epoch 34. Avg-Loss: 0.6777, Accuracy: 0.8029
# Validation-epoch 35. Avg-Loss: 0.6783, Accuracy: 0.7971
# Validation-epoch 36. Avg-Loss: 0.6659, Accuracy: 0.8029
# Validation-epoch 37. Avg-Loss: 0.6736, Accuracy: 0.8058
# Validation-epoch 38. Avg-Loss: 0.6715, Accuracy: 0.8116
# Validation-epoch 39. Avg-Loss: 0.6667, Accuracy: 0.8087
# Validation-epoch 40. Avg-Loss: 0.6713, Accuracy: 0.8116
# Validation-epoch 41. Avg-Loss: 0.6749, Accuracy: 0.8058
# Validation-epoch 42. Avg-Loss: 0.6563, Accuracy: 0.8058
# Validation-epoch 43. Avg-Loss: 0.6637, Accuracy: 0.8174
# Validation-epoch 44. Avg-Loss: 0.6659, Accuracy: 0.8087
# Validation-epoch 45. Avg-Loss: 0.6630, Accuracy: 0.8145
# Validation-epoch 46. Avg-Loss: 0.6574, Accuracy: 0.8116
# Validation-epoch 47. Avg-Loss: 0.6596, Accuracy: 0.8029
# Validation-epoch 48. Avg-Loss: 0.6572, Accuracy: 0.8145
# Validation-epoch 49. Avg-Loss: 0.6532, Accuracy: 0.8145
# Validation-epoch 50. Avg-Loss: 0.6649, Accuracy: 0.8058
# Validation-epoch 51. Avg-Loss: 0.6461, Accuracy: 0.8116
# Validation-epoch 52. Avg-Loss: 0.6548, Accuracy: 0.8058
# Validation-epoch 53. Avg-Loss: 0.6562, Accuracy: 0.8116
# Validation-epoch 54. Avg-Loss: 0.6552, Accuracy: 0.8145
# Validation-epoch 55. Avg-Loss: 0.6595, Accuracy: 0.8116
# Validation-epoch 56. Avg-Loss: 0.6542, Accuracy: 0.8087
# Validation-epoch 57. Avg-Loss: 0.6506, Accuracy: 0.8116
# Validation-epoch 58. Avg-Loss: 0.6645, Accuracy: 0.8029
# Validation-epoch 59. Avg-Loss: 0.6441, Accuracy: 0.8058
# Validation-epoch 60. Avg-Loss: 0.6482, Accuracy: 0.8116
# Validation-epoch 61. Avg-Loss: 0.6589, Accuracy: 0.8000
# Validation-epoch 62. Avg-Loss: 0.6500, Accuracy: 0.8029
# Validation-epoch 63. Avg-Loss: 0.6496, Accuracy: 0.8029
# Validation-epoch 64. Avg-Loss: 0.6516, Accuracy: 0.8029
# Validation-epoch 65. Avg-Loss: 0.6409, Accuracy: 0.8203
# Validation-epoch 66. Avg-Loss: 0.6492, Accuracy: 0.8145
# Validation-epoch 67. Avg-Loss: 0.6481, Accuracy: 0.8087
# Validation-epoch 68. Avg-Loss: 0.6455, Accuracy: 0.8087
# Validation-epoch 69. Avg-Loss: 0.6538, Accuracy: 0.8029
# Validation-epoch 70. Avg-Loss: 0.6382, Accuracy: 0.8145
# Validation-epoch 71. Avg-Loss: 0.6530, Accuracy: 0.8116
# Validation-epoch 72. Avg-Loss: 0.6510, Accuracy: 0.8174
# Validation-epoch 73. Avg-Loss: 0.6467, Accuracy: 0.8058
# Validation-epoch 74. Avg-Loss: 0.6415, Accuracy: 0.8145
# Validation-epoch 75. Avg-Loss: 0.6422, Accuracy: 0.8145
# Validation-epoch 76. Avg-Loss: 0.6414, Accuracy: 0.8116
# Validation-epoch 77. Avg-Loss: 0.6424, Accuracy: 0.8058
# Validation-epoch 78. Avg-Loss: 0.6429, Accuracy: 0.8116
# Validation-epoch 79. Avg-Loss: 0.6356, Accuracy: 0.8145
# Validation-epoch 80. Avg-Loss: 0.6380, Accuracy: 0.8116
# Validation-epoch 81. Avg-Loss: 0.6378, Accuracy: 0.8087
# Validation-epoch 82. Avg-Loss: 0.6381, Accuracy: 0.8087
# Validation-epoch 83. Avg-Loss: 0.6418, Accuracy: 0.8116
# Validation-epoch 84. Avg-Loss: 0.6426, Accuracy: 0.8145
# Validation-epoch 85. Avg-Loss: 0.6362, Accuracy: 0.8000
# Validation-epoch 86. Avg-Loss: 0.6364, Accuracy: 0.8116
# Validation-epoch 87. Avg-Loss: 0.6376, Accuracy: 0.8116
# Validation-epoch 88. Avg-Loss: 0.6383, Accuracy: 0.8116
# Validation-epoch 89. Avg-Loss: 0.6357, Accuracy: 0.8029
# Validation-epoch 90. Avg-Loss: 0.6436, Accuracy: 0.8087
# Validation-epoch 91. Avg-Loss: 0.6362, Accuracy: 0.8087
# Validation-epoch 92. Avg-Loss: 0.6293, Accuracy: 0.8116
# Validation-epoch 93. Avg-Loss: 0.6304, Accuracy: 0.8087
# Validation-epoch 94. Avg-Loss: 0.6300, Accuracy: 0.8058
# Validation-epoch 95. Avg-Loss: 0.6269, Accuracy: 0.8029
# Validation-epoch 96. Avg-Loss: 0.6287, Accuracy: 0.8116
# Validation-epoch 97. Avg-Loss: 0.6397, Accuracy: 0.8087
# Validation-epoch 98. Avg-Loss: 0.6323, Accuracy: 0.8116
# Validation-epoch 99. Avg-Loss: 0.6268, Accuracy: 0.8116

# %%
# Function we used during model evaluation.
def eval_predict(model, val_set, batchSize, num_workers=4):
    val_loader = torch.utils.data.DataLoader(dataset = val_set,
                                             batch_size = batchSize,
                                             num_workers = num_workers,
                                             shuffle = False)
    
    input_list = []
    label_list = []
    score_list = []
    
    model = model.cuda()
    model.eval()
    for (i, (inputs, labels)) in enumerate(val_loader):
        inputs = inputs.cuda()

        # Forward pass. (Prediction stage)
        scores = model(inputs)
        
        for (input, label, score) in zip(inputs, labels, scores):
            input_list.append(input.cpu())
            label_list.append(label.item())
            score_list.append(score.cpu())

        if (i + 1) % 100 == 0:
            print('Predicted %06d images' % (i * batchSize + len(ids)) )
    
    return input_list, label_list, score_list

# %%
# Predict on the validation set.
input_list, label_list, score_list = eval_predict(model_ft, val_set, 100)

# %%
# Get the predicted labels list.
pred_list = [score.max(0)[1].item() for score in score_list]

# %%
df_confusion = pd.crosstab(pd.Series(label_list, name='Actual'), pd.Series(pred_list, name='Predicted'))
df_conf_norm = df_confusion/ df_confusion.sum(axis=1)
import matplotlib.pyplot as plt
y = df_confusion.index.values
names = []
for i in y:
    names.append(class_names[i])

def plot_confusion_matrix(df_confusion, title='Confusion matrix', cmap=plt.cm.gray_r):
    plt.matshow(df_confusion, cmap=cmap) # imshow
    #plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(df_confusion.columns))
    plt.xticks(tick_marks, [i for i in names], rotation=90)
    plt.yticks(tick_marks, [i for i in names])
    #plt.tight_layout()
    plt.ylabel(df_confusion.index.name)
    plt.xlabel(df_confusion.columns.name)

plot_confusion_matrix(df_conf_norm)

# %%
def predict(model, test_set, batchSize, num_workers=4):
    test_loader = torch.utils.data.DataLoader(dataset = test_set,
                                             batch_size = batchSize,
                                             num_workers = num_workers,
                                             shuffle = False)
    
    submission = []
    
    model = model.cuda()
    model.eval()
    for (i, (inputs, ids)) in enumerate(test_loader):
        inputs = inputs.cuda()

        # Forward pass. (Prediction stage)
        scores = model(inputs)
        
        # Get predictions.
        _, max_labels = scores.max(1)
        
        # Add all the id & output into submission list
        for (id, max_label) in zip(ids, max_labels):
            submission.append({'Id':id, 'Predicted': max_label.item()})
        
        if (i + 1) % 100 == 0:
            print('Predicted %06d images' % (i * batchSize + len(ids)) )
    
    return pd.DataFrame(submission)

# %%
batchSize = 100

submission_df = predict(model_ft, test_set, batchSize)
# Out:
# Predicted 010000 images
# Predicted 020000 images
# Predicted 030000 images
# Predicted 040000 images

# %%
submission_df.to_csv('submission.csv',index=False)
